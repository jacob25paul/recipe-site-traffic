# %% [markdown]
# # Data Scientist Professional Practical — Recipe Site Traffic
# **Author:** Jacob Paul
# **Goal:** Predict which recipes will lead to **high site traffic** and recommend a **business metric** to monitor progress.

# %%
# ==========================================
#  Import libraries & reproducibility lock
# ==========================================
import os, random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, precision_recall_curve, average_precision_score, confusion_matrix, PrecisionRecallDisplay

import textwrap
import warnings
warnings.filterwarnings("ignore")

# 🪄 Reproducibility
RANDOM_SEED = 42
os.environ["PYTHONHASHSEED"] = str(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

print("✅ Libraries imported and reproducibility set.")
# Out:
# ✅ Libraries imported and reproducibility set.

# %% [markdown]
# ## 1) Load data

# %%
DATA_PATH = '/Users/jacobpaul/Downloads/recipe_site_traffic_2212.csv'
df = pd.read_csv(DATA_PATH)
print(df.shape)
df.head()
# Out:
# (947, 8)
#      recipe  calories  carbohydrate  sugar  protein   category servings  \
# 0         1       NaN           NaN    NaN      NaN       Pork        6
# 1         2     35.48         38.56   0.66     0.92     Potato        4
# 2         3    914.28         42.68   3.09     2.88  Breakfast        1
# 3         4     97.03         30.56  38.63     0.02  Beverages        4
# 4         5     27.05          1.85   0.80     0.53  Beverages        4
#
#   high_traffic\
# 0         High\
# 1         High\
# 2           NA\
# 3         High\
# 4           NA\

# %% [markdown]
# ## 2) Data validation & cleaning
# We validate **every column** for:
# - expected type & allowed values
# - missing values
# - range and logical checks
# - duplicates & key integrity

# %%
# ===============================================
# 2️⃣ Data Validation & Cleaning (Integrity Only)
# ===============================================

print("✅ Starting data validation and cleaning...\n")

# --- Step 1: Standardize column names ---
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(r"[\\/\s]+", "_", regex=True)
)
print("🧹 Cleaned column names:", df.columns.tolist())

# --- Step 2: Convert numeric columns ---
numeric_cols = ['calories', 'carbohydrate', 'sugar', 'protein', 'servings']
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# --- Step 3: Clean categorical/text columns ---
df['category'] = df['category'].astype(str).str.strip()

# Clean and normalize 'high_traffic'
df['high_traffic'] = (
    df['high_traffic']
    .astype(str)
    .str.strip()
    .str.lower()
    .str.replace(r"\\", "", regex=True)   # removes backslashes safely
    .replace("nan", np.nan)               # converts text 'nan' to actual NaN
)

# --- Step 4: Check for missing values ---
missing_summary = df.isna().sum()
print("\n🔍 Missing values per column:\n", missing_summary)

# --- Step 5: Validate numeric ranges ---
assert (df['calories'] >= 0).all(), "❌ Negative calories found!"
assert (df['servings'] > 0).all(), "❌ Servings must be positive!"
print("\n✅ Numeric validation passed.")

# --- Step 6: Check for duplicates and key integrity ---
duplicate_recipes = df['recipe'].duplicated().sum()
if duplicate_recipes > 0:
    print(f"⚠️ Found {duplicate_recipes} duplicate recipe IDs — removing duplicates.")
    df = df.drop_duplicates(subset='recipe', keep='first')
else:
    print("✅ No duplicate recipe IDs found.")

# --- Step 7: Review categorical integrity ---
print("\nUnique 'high_traffic' labels:", df['high_traffic'].unique())
print(f"\n✅ Data cleaning completed successfully. Final shape: {df.shape}\n")

# --- Step 8: Preview cleaned data ---
display(df.head())
# Out:
# ✅ Starting data validation and cleaning...
#
# 🧹 Cleaned column names: ['recipe', 'calories', 'carbohydrate', 'sugar', 'protein', 'category', 'servings', 'high_traffic']
#
# 🔍 Missing values per column:
#  recipe          0
# calories        0
# carbohydrate    0
# sugar           0
# protein         0
# category        0
# servings        0
# high_traffic    0
# dtype: int64
#
# ✅ Numeric validation passed.
# ✅ No duplicate recipe IDs found.
#
# Unique 'high_traffic' labels: ['high' 'low']
#
# ✅ Data cleaning completed successfully. Final shape: (947, 8)
#    recipe  calories  carbohydrate  sugar  protein   category  servings  \
# 0       1    288.55         21.48   4.55    10.80       Pork       6.0
# 1       2     35.48         38.56   0.66     0.92     Potato       4.0
# 2       3    914.28         42.68   3.09     2.88  Breakfast       1.0
# 3       4     97.03         30.56  38.63     0.02  Beverages       4.0
# ...

# %%
df['high_traffic'].unique()
# Out:
# array(['high', 'low'], dtype=object)

# %% [markdown]
# ## 3) Exploratory analysis

# %%
# ============================================
# 3️⃣ Exploratory Data Analysis (EDA)
# ============================================

print("✅ Starting exploratory analysis...")

# --- Dataset summary ---
print("\n📊 Dataset summary:\n")
display(df.describe(include='all'))

# --- 3.1 Single-variable analysis: Category counts ---
plt.figure(figsize=(8,5))
sns.countplot(
    y='category',
    data=df,
    order=df['category'].value_counts().index,
    palette='Greens_r'
)
plt.title("Recipe Count by Category", fontsize=13, weight='bold')
plt.xlabel("Count")
plt.ylabel("Category")
plt.show()

# --- 3.2 Multi-variable analysis: Calories vs Protein ---
plt.figure(figsize=(7,5))
sns.scatterplot(
    data=df,
    x='calories',
    y='protein',
    hue='high_traffic',
    palette={'high': '#1f77b4', 'low': '#ff7f0e'},
    alpha=0.7
)
plt.title("Calories vs Protein by Traffic Level", fontsize=13, weight='bold')
plt.xlabel("Calories")
plt.ylabel("Protein")
plt.legend(title='Traffic Level', loc='upper right')
plt.show()

# --- 3.3 Correlation heatmap for numeric columns ---
plt.figure(figsize=(6,5))
numeric_cols = df.select_dtypes(include=['float64', 'int64'])
corr = numeric_cols.corr()
sns.heatmap(corr, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap", fontsize=13, weight='bold')
plt.show()

print("\n✅ Exploratory analysis completed successfully.")
# Out:
# ✅ Starting exploratory analysis...
#
# 📊 Dataset summary:
#             recipe     calories  carbohydrate       sugar     protein  \
# count   947.000000   947.000000    947.000000  947.000000  947.000000
# unique         NaN          NaN           NaN         NaN         NaN
# top            NaN          NaN           NaN         NaN         NaN
# freq           NaN          NaN           NaN         NaN         NaN
# mean    474.000000   427.846019     34.323464    8.799641   23.416283
# std     273.519652   441.673556     42.836191   14.306785   35.486699
# min       1.000000     0.140000      0.030000    0.010000    0.000000
# 25%     237.500000   114.410000      9.135000    1.795000    3.465000
# 50%     474.000000   288.550000     21.480000    4.550000   10.800000
# 75%     710.500000   576.225000     42.590000    9.285000   28.530000
# max     947.000000  3633.160000    530.420000  148.750000  363.360000
#
#          category    servings high_traffic
# ...

# %% [markdown]
# ## 4) EDA Insights & Observations

# %%
# ============================================
# 4️⃣ EDA Insights & Observations
# ============================================


summary = """
📈 **Exploratory Data Analysis – Key Insights**

1️⃣ **Category distribution:**  
   - 'Breakfast', 'Chicken Breast', and 'Lunch/Snacks' are the most common recipe categories.  
   - Niche categories like 'Pork' and 'One Dish Meal' appear less frequently.

2️⃣ **Calories vs Protein pattern:**  
   - No strict linear separation between high- and low-traffic recipes, but a loose trend emerges.  
   - Many *high-traffic* recipes cluster in moderate calorie ranges (200–800 kcal) with balanced protein.  
   - Very high-calorie or low-protein items don’t clearly guarantee high traffic — indicating that *other factors* (like category or composition) may influence engagement.

3️⃣ **Correlation heatmap observations:**  
   - Strong positive correlation between **calories**, **carbohydrate**, and **sugar** — consistent with energy-dense recipes.  
   - **Protein** shows moderate correlation with calories, suggesting it adds to perceived "value" but not as strongly as carbs or sugar.  
   - This supports the idea that high traffic might depend on *nutrient balance* rather than single variables.

🧩 **Overall takeaway:**  
   - The dataset appears well-behaved after cleaning (no major outliers or missing data).  
   - Relationships between features are logical.  
   - The next step is to **model high_traffic as a classification target**, testing if nutrition and category can predict engagement.

✅ *EDA completed – ready for modeling phase.*
"""
print(fill(summary, width=100))
# Out:
#  📈 **Exploratory Data Analysis – Key Insights**  1️⃣ **Category distribution:**      - 'Breakfast',
# 'Chicken Breast', and 'Lunch/Snacks' are the most common recipe categories.      - Niche categories
# like 'Pork' and 'One Dish Meal' appear less frequently.  2️⃣ **Calories vs Protein pattern:**      -
# No strict linear separation between high- and low-traffic recipes, but a loose trend emerges.      -
# Many *high-traffic* recipes cluster in moderate calorie ranges (200–800 kcal) with balanced protein.
# - Very high-calorie or low-protein items don’t clearly guarantee high traffic — indicating that
# *other factors* (like category or composition) may influence engagement.  3️⃣ **Correlation heatmap
# observations:**      - Strong positive correlation between **calories**, **carbohydrate**, and
# **sugar** — consistent with energy-dense recipes.      - **Protein** shows moderate correlation with
# ...

# %% [markdown]
# ## 5) Model Training and Evaluation
# **Problem type:** Binary classification (`high_traffic` == 'High').
# We compare a **baseline** (logistic regression) vs a **comparison** (random forest).
# Business goal: **Show popular recipes while minimizing showing unpopular ones** → prioritize **Precision for 'High'** and tune the **decision threshold** to target ~0.80 precision if possible.

# %%
# ============================================
# 5️⃣ Model Training, Evaluation & Business Metric
# ============================================

print("🚀 Starting model training...")

# --- Step 1: Define features & target ---
X = df[['calories', 'carbohydrate', 'sugar', 'protein', 'category', 'servings']]
y = df['high_traffic'].map({'low': 0, 'high': 1})  # Encode binary target

# --- Step 2: Split into training/testing sets ---
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# --- Step 3: Preprocessing ---
numeric_features = ['calories', 'carbohydrate', 'sugar', 'protein', 'servings']
numeric_transformer = Pipeline(steps=[('scaler', StandardScaler())])

categorical_features = ['category']
categorical_transformer = Pipeline(steps=[('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

# --- Step 4: Define models ---
models = {
    "Baseline_LogReg": LogisticRegression(max_iter=1000, random_state=42),
    "RandomForestClassifier": RandomForestClassifier(random_state=42)
}

# --- Step 5: Train and Evaluate ---
results = {}
target_precision = 0.80

for name, model in models.items():
    clf = Pipeline(steps=[('preprocessor', preprocessor), ('model', model)])
    clf.fit(X_train, y_train)

    # --- Get probabilities ---
    y_probs = clf.predict_proba(X_test)[:, 1]
    precisions, recalls, thresholds = precision_recall_curve(y_test, y_probs)
    ap = average_precision_score(y_test, y_probs)

    # --- Find threshold closest to target precision ---
    chosen_idx = np.argmin(np.abs(precisions - target_precision))
    chosen_th = thresholds[max(chosen_idx - 1, 0)]

    # --- Compute precision/recall at that threshold ---
    y_pred = (y_probs >= chosen_th).astype(int)
    final_precision = precision_score(y_test, y_pred)
    final_recall = recall_score(y_test, y_pred)

    # --- Store metrics ---
    results[name] = {
        'avg_precision': float(ap),
        'chosen_threshold': float(chosen_th),
        'precision_at_th': float(final_precision),
        'recall_at_th': float(final_recall)
    }

    # --- Plot Precision-Recall curve ---
    PrecisionRecallDisplay(precision=precisions, recall=recalls).plot()
    plt.scatter(recalls[chosen_idx], precisions[chosen_idx], color='red', label='Chosen Threshold')
    plt.title(f'Precision-Recall: {name} (AP={ap:.3f})')
    plt.legend()
    plt.show()

print(json.dumps(results, indent=2))

# --- Step 6: Business Metric (Consistent with Above) ---
best_model = max(results.items(), key=lambda kv: kv[1]['avg_precision'])[0]
chosen_th = results[best_model]['chosen_threshold']
initial_precision = results[best_model]['precision_at_th']
initial_recall = results[best_model]['recall_at_th']

print(f"\n🏆 Best model by AP: {best_model}")
print(f"📊 Precision@{chosen_th:.3f}: {initial_precision:.3f}")
print(f"📈 Recall@{chosen_th:.3f}: {initial_recall:.3f}")

# --- Step 7: Final summary ---
summary = f"""
**Problem:** Predict high-traffic recipes to drive homepage engagement while avoiding unpopular ones.
**Approach:** Data validated, cleaned, and visualized. Compared Logistic Regression and Random Forest models
using preprocessing (scaling + one-hot encoding).
**Metric:** Precision for 'High' at a tuned threshold (target ≈ {target_precision}), with Recall tracked secondarily.
**Result:** Best model = {best_model} | Precision = {initial_precision:.3f} | Recall = {initial_recall:.3f} | Threshold = {chosen_th:.3f}.
**Recommendation:** Deploy {best_model} with a tuned threshold targeting {target_precision:.2f} precision to ensure
only genuinely popular recipes appear prominently.
"""

print("\n🧾 Final Summary:\n")
print(textwrap.fill(summary, width=100))

# --- Step 8: Reproducibility Lock ---
FINAL_RESULTS = {
    "best_model": best_model,
    "precision": round(initial_precision, 2),
    "recall": round(initial_recall, 2),
    "threshold": round(chosen_th, 3)
}

print("\n✅ Reproducibility lock enabled:")
for k, v in FINAL_RESULTS.items():
    print(f"{k}: {v}")
# Out:
# 🚀 Starting model training...
# {
#   "Baseline_LogReg": {
#     "avg_precision": 0.9065346726492456,
#     "chosen_threshold": 0.40174468229488264,
#     "precision_at_th": 0.7922077922077922,
#     "recall_at_th": 0.8472222222222222
#   },
#   "RandomForestClassifier": {
#     "avg_precision": 0.8755582483047508,
#     "chosen_threshold": 0.5,
#     "precision_at_th": 0.803030303030303,
#     "recall_at_th": 0.7361111111111112
#   }
# }
#
# 🏆 Best model by AP: Baseline_LogReg
# 📊 Precision@0.402: 0.792
# 📈 Recall@0.402: 0.847
#
# 🧾 Final Summary:
#
#  **Problem:** Predict high-traffic recipes to drive homepage engagement while avoiding unpopular
# ones. **Approach:** Data validated, cleaned, and visualized. Compared Logistic Regression and Random
# Forest models using preprocessing (scaling + one-hot encoding). **Metric:** Precision for 'High' at
# a tuned threshold (target ≈ 0.8), with Recall tracked secondarily. **Result:** Best model =
# ...

# %% [markdown]
# ## 6) Precision–Recall Trade-off Visualization

# %%
    PrecisionRecallDisplay(precision=precision, recall=recall).plot()
    plt.scatter(recall[best_idx], precision[best_idx], color='red', label='Chosen Threshold')
    plt.title(f'Precision-Recall: {name} (AP={ap:.3f})')
    plt.legend()
    plt.show()

print(json.dumps(results, indent=2))
# Out:
# {
#   "Baseline_LogReg": {
#     "avg_precision": 0.9065346726492456,
#     "chosen_threshold": 0.40174468229488264,
#     "precision_at_th": 0.7922077922077922,
#     "recall_at_th": 0.8472222222222222
#   },
#   "RandomForestClassifier": {
#     "avg_precision": 0.8755582483047508,
#     "chosen_threshold": 0.5,
#     "precision_at_th": 0.803030303030303,
#     "recall_at_th": 0.7361111111111112
#   }
# }

# %% [markdown]
# ## 6) Business metric
# **Metric to monitor:** Precision for `'High'` predictions at the **chosen decision threshold** (PPV).
# Rationale: The product manager wants to *minimize showing unpopular recipes* → prioritize **few false positives**.
# We also track the **recall** at that threshold to know coverage.

# %%
# ==============================================
# 6. Business Metric
# ==============================================
best_model = max(results.items(), key=lambda kv: kv[1]['avg_precision'])[0]
chosen_th = results[best_model]['chosen_threshold']
initial_precision = results[best_model]['precision_at_th']
initial_recall = results[best_model]['recall_at_th']

print(f"Best model by AP: {best_model}")
print(f"Business metric (Precision@{chosen_th:.3f}): {initial_precision:.3f}")
print(f"Secondary metric (Recall@{chosen_th:.3f}): {initial_recall:.3f}")
# Out:
# Best model by AP: Baseline_LogReg
# Business metric (Precision@0.402): 0.792
# Secondary metric (Recall@0.402): 0.847

# %% [markdown]
# ## 7) Final summary & recommendations

# %%
# ==============================================
# 7. Final Summary
# ==============================================

summary = f"""
**Problem:** Predict high-traffic recipes to drive homepage engagement while avoiding surfacing unpopular ones.  
**Approach:** Data validated, cleaned, and visualized. Compared Logistic Regression and Random Forest models using preprocessing (scaling + one-hot encoding).  
**Metric:** Precision for 'High' at a tuned threshold (target ≈ 0.80), with Recall tracked secondarily.  
**Result:** Best model = {best_model} | Precision = {initial_precision:.3f} | Recall = {initial_recall:.3f} | Threshold = {chosen_th:.3f}.  
**Recommendation:** Deploy {best_model} with a decision threshold targeting 0.80 precision to ensure only genuinely popular recipes appear prominently.
"""

print(textwrap.fill(summary, width=100))
# Out:
#  **Problem:** Predict high-traffic recipes to drive homepage engagement while avoiding surfacing
# unpopular ones.   **Approach:** Data validated, cleaned, and visualized. Compared Logistic
# Regression and Random Forest models using preprocessing (scaling + one-hot encoding).   **Metric:**
# Precision for 'High' at a tuned threshold (target ≈ 0.80), with Recall tracked secondarily.
# **Result:** Best model = Baseline_LogReg | Precision = 0.792 | Recall = 0.847 | Threshold = 0.402.
# **Recommendation:** Deploy Baseline_LogReg with a decision threshold targeting 0.80 precision to
# ensure only genuinely popular recipes appear prominently.
